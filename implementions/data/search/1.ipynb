# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [
    [2, 3, 4, 4, 4, 4],
    [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
    [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54],
    [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 36, 39, 42, 44, 46, 50, 56, 64, 76, 88, 100, 115, 118, 121, 124, 125, 126, 127, 136, 144, 155, 159, 164, 169, 180, 181, 181, 182, 180, 181, 177, 176, 183, 191, 188, 188, 194, 193, 198, 196, 200, 196, 192, 196, 198, 204, 203, 203, 208, 207, 216, 220, 220, 220, 220, 218, 218, 220, 218, 220, 220, 217, 220, 219, 220, 220, 220]
]

# 找到最长数据的长度
max_length = max(len(d) for d in data)

# 补全数据
padded_data = [d + [d[-1]] * (max_length - len(d)) for d in data]

# 绘制图形
colors = ["#7CBEEC", "#7EB57E", "#FF6F45", "#3274A1"]  # 每行数据的颜色
markers = ['o', '^', 's', 'D']  # 每行数据的标记形状

for i, d in enumerate(padded_data):
    x = list(range(max_length))
    plt.plot(x, d, label=f"Data {i+1}", color=colors[i], linewidth=2)
    plt.scatter(x, d, color=colors[i], edgecolor='black', marker=markers[i], s=50, zorder=3)

# 设置轴标签和标题
plt.xlabel("Index", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.title("Padded Data Plot", fontsize=16)

# 图例和网格
# plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# 显示图形
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [
    [2, 3, 4, 4, 4, 4],
    [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
    [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54],
    [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 36, 39, 42, 44, 46, 50, 56, 64, 76, 88, 100, 115, 118, 121, 124, 125, 126, 127, 136, 144, 155, 159, 164, 169, 180, 181, 181, 182, 180, 181, 177, 176, 183, 191, 188, 188, 194, 193, 198, 196, 200, 196, 192, 196, 198, 204, 203, 203, 208, 207, 216, 220, 220, 220, 220, 218, 218, 220, 218, 220, 220, 217, 220, 219, 220, 220, 220]
]

# 数据处理：去重并递增排序
processed_data = [sorted(set(d)) for d in data]

# 找到原始和去重数据的最大长度
max_length = max(len(d) for d in data + processed_data)

# 补全数据
padded_data = [d + [d[-1]] * (max_length - len(d)) for d in data]
processed_padded_data = [d + [d[-1]] * (max_length - len(d)) for d in processed_data]

# 设置绘图参数
scale = 1
plt.figure(figsize=(22 * scale, 12 * scale))
colors = ['#384B70', '#6A9C89', '#B8001F', '#FFF5E4']  # 每种方法的颜色
labels = ['HeaSolver', 'PenaltySolver', 'ChocoSolver', 'QtoSimplifyDiscardSegmentedSolver']

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(padded_data, processed_padded_data)):
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    
    # 绘制原始数据
    plt.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='-', linewidth=4)
    plt.scatter(x_orig, orig, color=colors[i], edgecolor='black', marker='o', s=100, zorder=3)
    
    # 绘制去重数据
    plt.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='--', linewidth=4)
    plt.scatter(x_proc, proc, color=colors[i], edgecolor='black', marker='^', s=100, zorder=3)

# 设置图例、标题、坐标轴标签
plt.xlabel("Normalized Index (%)", fontsize=20)
plt.ylabel("Value", fontsize=20)
plt.title("Comparison of Original and Processed Data", fontsize=24)
plt.legend(fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)

# 调整布局并显示
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [
    [2, 3, 4, 4, 4, 4],
    [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
    [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54],
    [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 36, 39, 42, 44, 46, 50, 56, 64, 76, 88, 100, 115, 118, 121, 124, 125, 126, 127, 136, 144, 155, 159, 164, 169, 180, 181, 181, 182, 180, 181, 177, 176, 183, 191, 188, 188, 194, 193, 198, 196, 200, 196, 192, 196, 198, 204, 203, 203, 208, 207, 216, 220, 220, 220, 220, 218, 218, 220, 218, 220, 220, 217, 220, 219, 220, 220, 220]
]
processed_data = [sorted(set(d)) for d in data]
# 去重并补全到原始长度
processed_data = []
for d in data:
    unique = sorted(set(d))  # 去重并排序
    # 创建映射，将原始索引映射到去重数据
    mapping = {i: unique[min(len(unique) - 1, unique.index(v))] for i, v in enumerate(d)}
    processed_data.append([mapping[i] for i in range(len(d))])

# 设置绘图参数
scale = 1
plt.figure(figsize=(22 * scale, 12 * scale))
colors = ['#384B70', '#6A9C89', '#B8001F', '#FFF5E4']  # 每种方法的颜色
labels = ['HeaSolver', 'PenaltySolver', 'ChocoSolver', 'QtoSimplifyDiscardSegmentedSolver']

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(data, processed_data)):
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    print(orig, proc)
    # 绘制原始数据
    plt.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='-', linewidth=4)
    plt.scatter(x_orig, orig, color=colors[i], edgecolor='black', marker='o', s=100, zorder=3)
    
    # 绘制去重数据
    plt.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='--', linewidth=4)
    plt.scatter(x_proc, proc, color=colors[i], edgecolor='black', marker='^', s=100, zorder=3)

# 设置图例、标题、坐标轴标签
plt.xlabel("Normalized Index (%)", fontsize=20)
plt.ylabel("Value", fontsize=20)
plt.title("Comparison of Original and Processed Data", fontsize=24)
plt.legend(fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# [2, 3, 4, 4, 4, 4] [2, 3, 4, 4, 4, 4]
# [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24] [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24]
# [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54] [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54]
# ...

# %%
# [2, 3, 4, 4, 4, 4] 
# [2, 3, 4, 4, 4, 4]
# [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24] 
# [2, 3, 5, 6, 7, 9, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24]
# [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54] 
# [2, 3, 5, 6, 7, 9, 11, 15, 19, 21, 23, 24, 25, 27, 31, 37, 43, 47, 48, 49, 50, 51, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54]
# [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 58, 54, 55, 56, 62, 62, 66, 60, 62, 62, 65, 65, 72, 78, 78, 85, 90, 93, 91, 94, 91, 92, 101, 96, 98, 105, 110, 118, 120, 127, 129, 123, 130, 133, 133, 130, 132, 130, 137, 141, 145, 145, 153, 151, 155, 156, 154, 150, 155, 153, 158, 163, 171, 174, 175, 189, 185, 180, 189, 181, 183, 186, 188, 188, 197, 204, 202, 203, 221, 219, 217, 221, 221, 218, 219, 219, 221, 222, 223, 221, 224, 223, 224, 224, 224] 
# [2, 3, 4, 7, 8, 9, 10, 12, 14, 16, 20, 24, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 54, 55, 56, 58, 60, 62, 65, 66, 72, 78, 85, 90, 91, 92, 93, 94, 96, 98, 101, 105, 110, 118, 120, 123, 127, 129, 130, 132, 133, 137, 141, 145, 150, 151, 153, 154, 155, 156, 158, 163, 171, 174, 175, 180, 181, 183, 185, 186, 188, 189, 197, 202, 203, 204, 217, 218, 219, 221, 222, 223, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224]
# 6
# 6
# 28
# 13
# 54
# 54
# 117
# 117
# print(len([2, 3, 4, 4, 4, 4]))
# print(len([2, 3, 4, 4, 4, 4]))
print(len([2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24])/28)
print(len([2, 3, 5, 6, 7, 9, 11, 13, 15, 16, 17, 19, 21, 24])/28)
print(len([2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54])/54)
print(len([2, 3, 5, 6, 7, 9, 11, 15, 19, 21, 23, 24, 25, 27, 31, 37, 43, 47, 48, 49, 50, 51, 52, 53, 54])/54)
print(len([2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 58, 54, 55, 56, 62, 62, 66, 60, 62, 62, 65, 65, 72, 78, 78, 85, 90, 93, 91, 94, 91, 92, 101, 96, 98, 105, 110, 118, 120, 127, 129, 123, 130, 133, 133, 130, 132, 130, 137, 141, 145, 145, 153, 151, 155, 156, 154, 150, 155, 153, 158, 163, 171, 174, 175, 189, 185, 180, 189, 181, 183, 186, 188, 188, 197, 204, 202, 203, 221, 219, 217, 221, 221, 218, 219, 219, 221, 222, 223, 221, 224, 223, 224] )/117)
print(len([2, 3, 4, 7, 8, 9, 10, 12, 14, 16, 20, 24, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 54, 55, 56, 58, 60, 62, 65, 66, 72, 78, 85, 90, 91, 92, 93, 94, 96, 98, 101, 105, 110, 118, 120, 123, 127, 129, 130, 132, 133, 137, 141, 145, 150, 151, 153, 154, 155, 156, 158, 163, 171, 174, 175, 180, 181, 183, 185, 186, 188, 189, 197, 202, 203, 204, 217, 218, 219, 221, 222, 223, 224])/117)
# Out:
# 0.6785714285714286
# 0.5
# 0.7962962962962963
# 0.46296296296296297
# 0.9829059829059829
# 0.7094017094017094

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [
    [2, 3, 4, 4, 4, 4],
    [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
    [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54],
    [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 58, 54, 55, 56, 62, 62, 66, 60, 62, 62, 65, 65, 72, 78, 78, 85, 90, 93, 91, 94, 91, 92, 101, 96, 98, 105, 110, 118, 120, 127, 129, 123, 130, 133, 133, 130, 132, 130, 137, 141, 145, 145, 153, 151, 155, 156, 154, 150, 155, 153, 158, 163, 171, 174, 175, 189, 185, 180, 189, 181, 183, 186, 188, 188, 197, 204, 202, 203, 221, 219, 217, 221, 221, 218, 219, 219, 221, 222, 223, 221, 224, 223, 224, 224, 224]
]

# 去重并递增后补全到原始长度
processed_data = []
for d in data:
    unique = sorted(set(d))  # 去重并递增
    # 补全到原始长度
    filled = unique + [unique[-1]] * (len(d) - len(unique))
    processed_data.append(filled)

# 设置绘图参数
scale = 1
plt.figure(figsize=(22 * scale, 12 * scale))
colors = ['#384B70', '#6A9C89', '#B8001F', '#FFF5E4']  # 每种方法的颜色
labels = ['HeaSolver', 'PenaltySolver', 'ChocoSolver', 'QtoSimplifyDiscardSegmentedSolver']

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(data, processed_data)):
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    print(orig, proc)
    # 绘制原始数据
    plt.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='-', linewidth=4)
    plt.scatter(x_orig, orig, color=colors[i],linewidths=2, edgecolor='black', marker='o', s=1000, zorder=3)
    
    # 绘制去重数据
    plt.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='--', linewidth=4)
    plt.scatter(x_proc, proc, color=colors[i],linewidths=2, edgecolor='black', marker='^', s=1000, zorder=3)

# 设置图例、标题、坐标轴标签
plt.xlabel("Normalized Index (%)")
plt.ylabel("Value")
plt.grid(True, linestyle='--', alpha=0.6)

# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# [2, 3, 4, 4, 4, 4] [2, 3, 4, 4, 4, 4]
# [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24] [2, 3, 5, 6, 7, 9, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24]
# [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54] [2, 3, 5, 6, 7, 9, 11, 15, 19, 21, 23, 24, 25, 27, 31, 37, 43, 47, 48, 49, 50, 51, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [
    [2, 3, 4, 4, 4, 4],
    [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
    [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54],
    [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 58, 54, 55, 56, 62, 62, 66, 60, 62, 62, 65, 65, 72, 78, 78, 85, 90, 93, 91, 94, 91, 92, 101, 96, 98, 105, 110, 118, 120, 127, 129, 123, 130, 133, 133, 130, 132, 130, 137, 141, 145, 145, 153, 151, 155, 156, 154, 150, 155, 153, 158, 163, 171, 174, 175, 189, 185, 180, 189, 181, 183, 186, 188, 188, 197, 204, 202, 203, 221, 219, 217, 221, 221, 218, 219, 219, 221, 222, 223, 221, 224, 223, 224, 224, 224],
]

# 去重并递增后补全到原始长度
processed_data = []
for d in data:
    unique = sorted(set(d))  # 去重并递增
    # 补全到原始长度
    filled = unique + [unique[-1]] * (len(d) - len(unique))
    processed_data.append(filled)

# 设置绘图参数
scale = 1
plt.figure(figsize=(22 * scale, 10 * scale))
colors = ['#FFF5E4','#384B70' ,'#B8001F' , '#6A9C89']  # 每种方法的颜色
labels = ['HeaSolver', 'PenaltySolver', 'ChocoSolver', 'QtoSimplifyDiscardSegmentedSolver']

ax = plt.axes((0, 0, 0.62, 1))
# 函数：提取最多30个均匀分布的点
def get_uniform_points(x, y, max_points=30):
    """基于线性插值计算均匀分布的点"""
    indices = np.linspace(0, len(x) - 1, num=max_points, dtype=int)
    x_uniform = [x[i] for i in indices]
    y_uniform = [y[i] for i in indices]
    return x_uniform, y_uniform

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(data, processed_data)):
    if i == 0:
        continue
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    
    # 原始数据均匀取点
    x_orig_uniform, y_orig_uniform = get_uniform_points(x_orig, orig)
    x_proc_uniform, y_proc_uniform = get_uniform_points(x_proc, proc)
    
    # 绘制原始数据
    ax.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='--', linewidth=7)
    # ax.scatter(x_orig_uniform, y_orig_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='o', s=500, zorder=3)
    
    # 绘制去重数据
    ax.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='-', linewidth=7)
    # ax.scatter(x_proc_uniform, y_proc_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='^', s=500, zorder=4)
ax1 = plt.axes((0.02, 0.6, 0.2, 0.35))
# 函数：提取最多30个均匀分布的点
def get_uniform_points(x, y, max_points=200):
    """基于线性插值计算均匀分布的点"""
    indices = np.linspace(0, len(x) - 1, num=max_points, dtype=int)
    x_uniform = [x[i] for i in indices]
    y_uniform = [y[i] for i in indices]
    return x_uniform, y_uniform

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(data, processed_data)):
    if i in [0, 1]:
        continue
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    
    # 原始数据均匀取点
    x_orig_uniform, y_orig_uniform = get_uniform_points(x_orig, orig)
    x_proc_uniform, y_proc_uniform = get_uniform_points(x_proc, proc)
    
    # 绘制原始数据
    ax1.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='--', linewidth=5)
    # ax1.scatter(x_orig_uniform, y_orig_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='o', s=500, zorder=3)
    
    # 绘制去重数据
    ax1.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='-', linewidth=5)
    # ax1.scatter(x_proc_uniform, y_proc_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='^', s=500, zorder=4)
    ax1.set_xlim(0, 16)
    ax1.set_ylim(2, 20)
    ax1.set_xticks([])
    ax1.set_yticks([])
# 设置 ax3 的外边框为虚线
for spine in ax1.spines.values():
    spine.set_linestyle((0, (10, 5)))  # 设置为虚线
    spine.set_linewidth(2)    # 设置线宽
    spine.set_color('black')  # 设置颜色
    
# 设置图例、标题、坐标轴标签
ax.set_xlabel("tau(%)")
ax.set_ylabel("#state")
# ax.set_grid(True, linestyle='--', alpha=0.6)
# plt.legend()
height = [68,80,98]
height2 = [50,46,71]
ax3 = plt.axes((0.7, 0, 0.3, 1))

for i in range(3):
    ax3.barh(
        i, height[i], height=0.2, linewidth=3,  # 改为 barh 并调整 height
        color=colors[i + 1], edgecolor="black",
        alpha=0.5  # 设置透明度
    )
    ax3.barh(
        i, height2[i], height=0.2, linewidth=3,  # 同样改为 barh 并调整 height
        color=colors[i + 1], edgecolor="black",
        alpha=1  # 设置透明度
    )
    ax3.set_ylim(-0.5,2.5)
    ax3.set_yticks([])
    ax3.set_xlabel("tau(%)")


plt.savefig('1.svg', bbox_inches='tight')
# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3156774/991583505.py:117: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [
    [2, 3, 4, 4, 4, 4],
    [2, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 11, 13, 15, 16, 17, 19, 21, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24],
    [2, 3, 3, 3, 3, 3, 5, 6, 7, 7, 7, 9, 11, 15, 19, 19, 21, 23, 24, 25, 27, 31, 37, 43, 48, 48, 47, 48, 48, 51, 51, 50, 51, 52, 50, 52, 49, 53, 53, 52, 52, 53, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54, 54],
    [2, 3, 4, 4, 4, 4, 4, 4, 4, 7, 8, 9, 10, 10, 10, 10, 12, 14, 16, 20, 24, 28, 28, 32, 34, 39, 42, 44, 45, 46, 48, 51, 58, 54, 55, 56, 62, 62, 66, 60, 62, 62, 65, 65, 72, 78, 78, 85, 90, 93, 91, 94, 91, 92, 101, 96, 98, 105, 110, 118, 120, 127, 129, 123, 130, 133, 133, 130, 132, 130, 137, 141, 145, 145, 153, 151, 155, 156, 154, 150, 155, 153, 158, 163, 171, 174, 175, 189, 185, 180, 189, 181, 183, 186, 188, 188, 197, 204, 202, 203, 221, 219, 217, 221, 221, 218, 219, 219, 221, 222, 223, 221, 224, 223, 224, 224, 224],
]

# 去重并递增后补全到原始长度
processed_data = []
for d in data:
    unique = sorted(set(d))  # 去重并递增
    # 补全到原始长度
    filled = unique + [unique[-1]] * (len(d) - len(unique))
    processed_data.append(filled)

# 设置绘图参数
scale = 1
plt.figure(figsize=(22 * scale, 12 * scale))
colors = ['#FFF5E4','#384B70' ,'#B8001F' , '#6A9C89']  # 每种方法的颜色
labels = ['HeaSolver', 'PenaltySolver', 'ChocoSolver', 'QtoSimplifyDiscardSegmentedSolver']

ax = plt.axes((0, 0, 0.5, 1))
# 函数：提取最多30个均匀分布的点
def get_uniform_points(x, y, max_points=30):
    """基于线性插值计算均匀分布的点"""
    indices = np.linspace(0, len(x) - 1, num=max_points, dtype=int)
    x_uniform = [x[i] for i in indices]
    y_uniform = [y[i] for i in indices]
    return x_uniform, y_uniform

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(data, processed_data)):
    if i == 0:
        continue
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    
    # 原始数据均匀取点
    x_orig_uniform, y_orig_uniform = get_uniform_points(x_orig, orig)
    x_proc_uniform, y_proc_uniform = get_uniform_points(x_proc, proc)
    
    # 绘制原始数据
    ax.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='--', linewidth=7)
    # ax.scatter(x_orig_uniform, y_orig_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='o', s=500, zorder=3)
    
    # 绘制去重数据
    ax.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='-', linewidth=7)
    # ax.scatter(x_proc_uniform, y_proc_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='^', s=500, zorder=4)
ax1 = plt.axes((0, 0.5, 0.15, 0.5))
# 函数：提取最多30个均匀分布的点
def get_uniform_points(x, y, max_points=200):
    """基于线性插值计算均匀分布的点"""
    indices = np.linspace(0, len(x) - 1, num=max_points, dtype=int)
    x_uniform = [x[i] for i in indices]
    y_uniform = [y[i] for i in indices]
    return x_uniform, y_uniform

# 绘制原始数据和去重数据
for i, (orig, proc) in enumerate(zip(data, processed_data)):
    if i in [0, 1]:
        continue
    x_orig = [j / (len(orig) - 1) * 100 for j in range(len(orig))]
    x_proc = [j / (len(proc) - 1) * 100 for j in range(len(proc))]
    
    # 原始数据均匀取点
    x_orig_uniform, y_orig_uniform = get_uniform_points(x_orig, orig)
    x_proc_uniform, y_proc_uniform = get_uniform_points(x_proc, proc)
    
    # 绘制原始数据
    ax1.plot(x_orig, orig, label=f'{labels[i]} (Original)', color=colors[i], linestyle='--', linewidth=5)
    # ax1.scatter(x_orig_uniform, y_orig_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='o', s=500, zorder=3)
    
    # 绘制去重数据
    ax1.plot(x_proc, proc, label=f'{labels[i]} (Processed)', color=colors[i], linestyle='-', linewidth=5)
    # ax1.scatter(x_proc_uniform, y_proc_uniform, color=colors[i], linewidths=3, edgecolor='black', marker='^', s=500, zorder=4)
    ax1.set_xlim(0, 15)
    ax1.set_ylim(0, 50)
    ax1.set_xticks([])
    ax1.set_yticks([])
# 设置图例、标题、坐标轴标签
ax.set_xlabel("tau(%)")
ax.set_ylabel("#state")
# ax.set_grid(True, linestyle='--', alpha=0.6)
# plt.legend()
height = [68,80,98]
height2 = [50,46,71]
ax3 = plt.axes((0.65, 0, 0.35, 1))

for i in range(3):
    ax3.bar(
        i, height[i], width=0.4, linewidth=3,
        color=colors[i + 1], edgecolor="black",
        alpha=0.5  # 设置透明度
    )
    ax3.bar(
        i, height2[i], width=0.4, linewidth=3,
        color=colors[i+1], edgecolor="black",
        alpha=1  # 设置透明度
    )
    ax3.set_xlim(-0.6, 2.6)
    ax3.set_xlim(-0.6, 2.6)
    ax3.set_ylabel("tau(%)")
    

plt.savefig('1.svg', bbox_inches='tight')
# 调整布局并显示
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3156774/3989494254.py:111: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
